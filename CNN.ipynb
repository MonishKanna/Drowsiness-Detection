# %% [markdown]
# # CNN

# %%
import os
import pathlib
import kaggle
import shutil
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix, roc_curve, f1_score, precision_score, recall_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Flatten, Dense, MaxPool2D, Conv2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers

tf.__version__
# Out:
# '2.3.1'

# %% [markdown]
# ## Fetch Dataset from Kaggle

# %%
dir_path = os.path.dirname(__file__)

# require you to first put your kaggle api key locally
kaggle.api.authenticate()

kaggle.api.dataset_download_files('dheerajperumandla/drowsiness-dataset', path=dir_path, unzip=True)

shutil.move(dir_path + "/train", dir_path + "/test")
shutil.move(dir_path + "/test/Closed", dir_path + "/test/Closed_Eyes")
shutil.move(dir_path + "/test/Open", dir_path + "/test/Open_Eyes")

kaggle.api.dataset_download_files('prasadvpatil/mrl-dataset', path=dir_path, unzip=True)

shutil.rmtree(dir_path + "/test/yawn")
shutil.rmtree(dir_path + "/test/no_yawn")

# %% [markdown]
# ## Data Pre-Processing

# %%
cwd = os.getcwd()
DATA_LIST = os.listdir(cwd + '/train')
TRAIN_DIR  = cwd + '/train'
TEST_DIR = cwd + '/test'
IMAGE_SIZE = (50, 50)
BATCH = 32
EPOCHS = 30
LR = 0.00001

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   featurewise_center = True,
                                   featurewise_std_normalization = True,
                                   validation_split = 0.2)


train_batches = train_datagen.flow_from_directory(TRAIN_DIR,target_size=IMAGE_SIZE,
                                                  shuffle=True,batch_size=BATCH,
                                                  subset = "training",seed=42,
                                                  class_mode="binary")

valid_batches = train_datagen.flow_from_directory(TRAIN_DIR,target_size=IMAGE_SIZE,
                                                  shuffle=True,batch_size=BATCH,
                                                  subset = "validation",
                                                  seed=42,class_mode="binary")
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %% [markdown]
# ## CNN Architecture

# %%
model = Sequential()
model.add(Conv2D(16, (3, 3), name='conv2d_1', activation='relu', input_shape=(50,50,3)))
model.add(MaxPool2D(2,2))
model.add(BatchNormalization())          

model.add(Conv2D(32, (3, 3), name='conv2d_2', activation='relu'))
model.add(MaxPool2D(2,2)) 
model.add(BatchNormalization())          

model.add(Conv2D(64, (3, 3), name='conv2d_3', activation='relu'))
model.add(MaxPool2D(2,2)) 
model.add(BatchNormalization()) 

model.add(Flatten())
model.add(Dense(64,activation="relu",name="dense_"))
model.add(Dense(1,activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 24, 16)        64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 11, 11, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense_ (Dense)               (None, 64)                65600
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 89,697
# Trainable params: 89,473
# Non-trainable params: 224
# _________________________________________________________________
# 2022-12-17 16:19:51.714876: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-17 16:19:51.732345: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f7fa3b8e810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-12-17 16:19:51.732361: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## CNN Training

# %%
print(len(train_batches))
print(len(valid_batches))

STEP_TRAIN=train_batches.n//train_batches.batch_size
STEP_VALID=valid_batches.n//valid_batches.batch_size

opt = tf.keras.optimizers.Adam(learning_rate=LR)

model.compile(optimizer=opt,
              loss="binary_crossentropy",
              metrics=['accuracy'])

history = model.fit(train_batches, 
                    steps_per_epoch=STEP_TRAIN, 
                    epochs=EPOCHS, 
                    validation_data=valid_batches, 
                    validation_steps=STEP_VALID)
# Out:
# 100
# 25
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f7f95e14200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f7f95e14200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# /opt/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /opt/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
#  99/100 [============================>.] - ETA: 0s - loss: 0.4424 - accuracy: 0.7996WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f7f964e9290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f7f964e9290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100/100 [==============================] - 4s 42ms/step - loss: 0.4402 - accuracy: 0.8012 - val_loss: 0.7083 - val_accuracy: 0.5000
# Epoch 2/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.2486 - accuracy: 0.9306 - val_loss: 0.7860 - val_accuracy: 0.5000
# Epoch 3/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.1732 - accuracy: 0.9694 - val_loss: 0.8385 - val_accuracy: 0.5000
# Epoch 4/30
# 100/100 [==============================] - 4s 36ms/step - loss: 0.1294 - accuracy: 0.9809 - val_loss: 0.7942 - val_accuracy: 0.5013
# Epoch 5/30
# 100/100 [==============================] - 4s 36ms/step - loss: 0.1010 - accuracy: 0.9841 - val_loss: 0.6051 - val_accuracy: 0.5525
# Epoch 6/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0848 - accuracy: 0.9862 - val_loss: 0.3999 - val_accuracy: 0.7725
# Epoch 7/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0706 - accuracy: 0.9869 - val_loss: 0.2675 - val_accuracy: 0.8913
# Epoch 8/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0591 - accuracy: 0.9912 - val_loss: 0.2064 - val_accuracy: 0.9262
# Epoch 9/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0525 - accuracy: 0.9912 - val_loss: 0.1737 - val_accuracy: 0.9425
# Epoch 10/30
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0456 - accuracy: 0.9928 - val_loss: 0.1525 - val_accuracy: 0.9588
# Epoch 11/30
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0418 - accuracy: 0.9928 - val_loss: 0.1429 - val_accuracy: 0.9613
# Epoch 12/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0369 - accuracy: 0.9937 - val_loss: 0.1321 - val_accuracy: 0.9625
# Epoch 13/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0340 - accuracy: 0.9937 - val_loss: 0.1249 - val_accuracy: 0.9650
# Epoch 14/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0291 - accuracy: 0.9953 - val_loss: 0.1200 - val_accuracy: 0.9638
# Epoch 15/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0287 - accuracy: 0.9947 - val_loss: 0.1152 - val_accuracy: 0.9638
# Epoch 16/30
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0257 - accuracy: 0.9956 - val_loss: 0.1052 - val_accuracy: 0.9700
# Epoch 17/30
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0241 - accuracy: 0.9962 - val_loss: 0.1049 - val_accuracy: 0.9675
# Epoch 18/30
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0203 - accuracy: 0.9966 - val_loss: 0.0979 - val_accuracy: 0.9688
# Epoch 19/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0181 - accuracy: 0.9978 - val_loss: 0.0959 - val_accuracy: 0.9688
# Epoch 20/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0184 - accuracy: 0.9984 - val_loss: 0.0916 - val_accuracy: 0.9712
# Epoch 21/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0144 - accuracy: 0.9991 - val_loss: 0.0917 - val_accuracy: 0.9700
# Epoch 22/30
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0136 - accuracy: 0.9991 - val_loss: 0.0906 - val_accuracy: 0.9700
# Epoch 23/30
# 100/100 [==============================] - 4s 43ms/step - loss: 0.0129 - accuracy: 0.9987 - val_loss: 0.0856 - val_accuracy: 0.9725
# Epoch 24/30
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0118 - accuracy: 0.9984 - val_loss: 0.0856 - val_accuracy: 0.9725
# Epoch 25/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0124 - accuracy: 0.9981 - val_loss: 0.0823 - val_accuracy: 0.9725
# Epoch 26/30
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0098 - accuracy: 0.9994 - val_loss: 0.0795 - val_accuracy: 0.9725
# Epoch 27/30
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0090 - accuracy: 0.9991 - val_loss: 0.0735 - val_accuracy: 0.9725
# Epoch 28/30
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.0771 - val_accuracy: 0.9725
# Epoch 29/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0080 - accuracy: 0.9997 - val_loss: 0.0775 - val_accuracy: 0.9725
# Epoch 30/30
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0071 - accuracy: 0.9997 - val_loss: 0.0707 - val_accuracy: 0.9737

# %% [markdown]
# ## Training Results

# %%
plt.figure(1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label = 'Test')
plt.title("Accuracy over " + str(EPOCHS) + " epochs")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid()

plt.figure(2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label = 'Test')
plt.title("Loss over " + str(EPOCHS) + " epochs")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid()

plt.show()

# %% [markdown]
# ## Testing Performance

# %%
model = tf.keras.models.load_model('../model/cnn_model.h5')

# %%
def to_grayscale_then_rgb(image):
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.grayscale_to_rgb(image)
    return image


test_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=to_grayscale_then_rgb)
test_batches = test_datagen.flow_from_directory(TEST_DIR,target_size=IMAGE_SIZE,
                                                  batch_size=1,shuffle=False,seed=42,class_mode="binary")

test_batches.reset()
print(len(test_batches))
model_eval = model.evaluate(test_batches,steps = np.ceil(len(test_batches)),verbose = 1)
print('Test loss:' , model_eval[0])
print('Test accuracy:',model_eval[1])
# Out:
# Found 1452 images belonging to 2 classes.
# 1452
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f7f96ef3440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f7f96ef3440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1452/1452 [==============================] - 5s 4ms/step - loss: 0.3014 - accuracy: 0.8850
# Test loss: 0.30139026045799255
# Test accuracy: 0.8849862217903137

# %%
y_pred_probs = model.predict(test_batches,steps = np.ceil(len(test_batches)),verbose = 1)
y_preds = y_pred_probs >= 0.5
y_labels = test_batches.labels
labels_class = ["Closed Eyes", "Open Eyes"]
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f7f95edaef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f7f95edaef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1452/1452 [==============================] - 5s 3ms/step

# %% [markdown]
# ### Confusion Matrix

# %%
cm=confusion_matrix(y_preds,y_labels)
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labels_class)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax);

# %% [markdown]
# ### ROC Curve

# %%
fpr, tpr, _ = metrics.roc_curve(y_labels,  y_pred_probs)
auc = metrics.roc_auc_score(y_labels, y_pred_probs)

plt.plot(fpr,tpr,label="AUC="+str(auc),color="darkorange")
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
print('Precision: %.3f' % precision_score(y_labels, y_preds))
print('Recall: %.3f' % recall_score(y_labels, y_preds))
print('F1 Score: %.3f' % f1_score(y_labels, y_preds))
# Out:
# Precision: 0.886
# Recall: 0.884
# F1 Score: 0.885
